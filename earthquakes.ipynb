# %% [markdown]
# # Earthquakes map and classification

# %%
###### ------------------- Main libraries -------------------################
import pandas as pd
import numpy as np 
from pprint import pprint
import folium 
from folium.plugins import HeatMap
from folium.plugins import MarkerCluster
import datetime

# %%
earthquake = pd.read_csv('./earthquakes.csv')
earthquake.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
earthquake['date_time']  = earthquake.Date +' '+ earthquake.Time
earthquake.head(2)
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
#
#    Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# 0                  NaN               NaN               NaN  ISCGEM860706
# 1                  NaN               NaN               NaN  ISCGEM860737
#
#    Source Location Source Magnitude Source     Status            date_time
# 0  ISCGEM          ISCGEM           ISCGEM  Automatic  01/02/1965 13:44:18
# 1  ISCGEM          ISCGEM           ISCGEM  Automatic  01/04/1965 11:29:49
#
# [2 rows x 22 columns]

# %%
earthquake['color'] = np.where(earthquake.Magnitude<=4,'green',
                               np.where(earthquake.Magnitude>=6,'red',
                                       np.where((earthquake.Magnitude<6) & (earthquake.Magnitude>4),'blue','darkblue')))
earthquake.head(2)
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Horizontal Distance  \
# 0                     NaN        6.0             MW  ...                  NaN
# 1                     NaN        5.8             MW  ...                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source  Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM           ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM           ISCGEM
#
#   Magnitude Source     Status            date_time color
# 0           ISCGEM  Automatic  01/02/1965 13:44:18   red
# 1           ISCGEM  Automatic  01/04/1965 11:29:49  blue
#
# [2 rows x 23 columns]

# %%
map1 = folium.Map(location = [19.4978,-99.1269], zoom_start = 10)
locations = earthquake[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
#for point in range(0,len(locationlist)):
#    folium.Marker(locationlist[point], popup=[general_ags['MUNICIPIO'],general_ags.DEFUNCION]).add_to(map1)
#map1
marker_cluster = MarkerCluster().add_to(map1)
iconname = 'bolt'
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=earthquake['Magnitude'][point],
                 icon=folium.Icon(color=earthquake["color"][point], icon_color='white', icon='glyphicon-pushpin', angle=0, prefix='glyphicon')).add_to(marker_cluster)
#map1.save('./mx_covid.html')
#map1

# %%
m = folium.Map([19.4978, -99.1269], zoom_start=11)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
earth = earthquake[['Latitude', 'Longitude']]

# plot heatmap
m.add_child(HeatMap(earth, radius=15))
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map1.save('./earth.html')
m.save('./heat.html')
